# %%
import pandas as pd

# %%
df = pd.read_csv('students.csv')

# %%
df
# Out:
#     Name   Age  Marks       City
# 0    Ali  20.0   85.0     Lahore
# 1   Sara  21.0   90.0    Karachi
# 2  Ahmad  19.0    NaN     Lahore
# 3  Aysha  20.0   88.0  Islamabad
# 4  Usman   NaN   70.0        NaN

# %%
df.shape
# Out:
# (5, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Marks', 'City'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      str
#  1   Age     4 non-null      float64
#  2   Marks   4 non-null      float64
#  3   City    4 non-null      str
# dtypes: float64(2), str(2)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#              Age      Marks
# count   4.000000   4.000000
# mean   20.000000  83.250000
# std     0.816497   9.069179
# min    19.000000  70.000000
# 25%    19.750000  81.250000
# 50%    20.000000  86.500000
# 75%    20.250000  88.500000
# max    21.000000  90.000000

# %%
df.head()
# Out:
#     Name   Age  Marks       City
# 0    Ali  20.0   85.0     Lahore
# 1   Sara  21.0   90.0    Karachi
# 2  Ahmad  19.0    NaN     Lahore
# 3  Aysha  20.0   88.0  Islamabad
# 4  Usman   NaN   70.0        NaN

# %%
df[['Name', 'Age', 'City']]
# Out:
#     Name   Age       City
# 0    Ali  20.0     Lahore
# 1   Sara  21.0    Karachi
# 2  Ahmad  19.0     Lahore
# 3  Aysha  20.0  Islamabad
# 4  Usman   NaN        NaN

# %%
df.loc[0:0]
# Out:
#   Name   Age  Marks    City
# 0  Ali  20.0   85.0  Lahore

# %%
df[df['Marks'] < 80]
# Out:
#     Name  Age  Marks City
# 4  Usman  NaN   70.0  NaN

# %%
df.isnull().sum()
# Out:
# Name     0
# Age      1
# Marks    1
# City     1
# dtype: int64

# %%
df
# Out:
#     Name   Age  Marks       City
# 0    Ali  20.0   85.0     Lahore
# 1   Sara  21.0   90.0    Karachi
# 2  Ahmad  19.0    NaN     Lahore
# 3  Aysha  20.0   88.0  Islamabad
# 4  Usman   NaN   70.0        NaN

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df
# Out:
#     Name   Age  Marks       City
# 0    Ali  20.0   85.0     Lahore
# 1   Sara  21.0   90.0    Karachi
# 2  Ahmad  19.0    NaN     Lahore
# 3  Aysha  20.0   88.0  Islamabad
# 4  Usman  20.0   70.0        NaN

# %%
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())

# %%
df
# Out:
#     Name   Age  Marks       City
# 0    Ali  20.0  85.00     Lahore
# 1   Sara  21.0  90.00    Karachi
# 2  Ahmad  19.0  83.25     Lahore
# 3  Aysha  20.0  88.00  Islamabad
# 4  Usman  20.0  70.00        NaN

# %%
df["City"]=df["City"].fillna(df["City"].mode())

# %%
df
# Out:
#     Name   Age  Marks       City
# 0    Ali  20.0  85.00     Lahore
# 1   Sara  21.0  90.00    Karachi
# 2  Ahmad  19.0  83.25     Lahore
# 3  Aysha  20.0  88.00  Islamabad
# 4  Usman  20.0  70.00        NaN

# %%
df["Result"] = df["Marks"].apply(lambda x: "Pass" if x > 70 else "Fail")

# %%
df
# Out:
#     Name   Age  Marks       City Result
# 0    Ali  20.0  85.00     Lahore   Pass
# 1   Sara  21.0  90.00    Karachi   Pass
# 2  Ahmad  19.0  83.25     Lahore   Pass
# 3  Aysha  20.0  88.00  Islamabad   Pass
# 4  Usman  20.0  70.00        NaN   Fail

# %%
df.head()
# Out:
#     Name   Age  Marks       City Result
# 0    Ali  20.0  85.00     Lahore   Pass
# 1   Sara  21.0  90.00    Karachi   Pass
# 2  Ahmad  19.0  83.25     Lahore   Pass
# 3  Aysha  20.0  88.00  Islamabad   Pass
# 4  Usman  20.0  70.00        NaN   Fail
